# %%
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/martynodlrr/.local/lib/python3.10/site-packages (2.3.0+cu118)
# Requirement already satisfied: torchvision in /home/martynodlrr/.local/lib/python3.10/site-packages (0.18.0+cu118)
# Collecting cython
#   Downloading Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.8.86)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: sympy in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: filelock in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (8.7.0.84)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: networkx in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: triton==2.3.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (2.3.0)
# Requirement already satisfied: fsspec in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch) (4.10.0)
# Requirement already satisfied: numpy in /home/martynodlrr/.local/lib/python3.10/site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/martynodlrr/.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: cython
# Successfully installed cython-3.0.10
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-6crdee1b
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-6crdee1b
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from pycocotools==2.0) (69.0.2)
# Requirement already satisfied: cython>=0.27.3 in /home/martynodlrr/.local/lib/python3.10/site-packages (from pycocotools==2.0) (3.0.10)
# Requirement already satisfied: matplotlib>=2.1.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from pycocotools==2.0) (3.8.4)
# Requirement already satisfied: numpy>=1.21 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.26.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: pillow>=8 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (10.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (24.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.51.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375681 sha256=5f7d5083289f1dff3ecd04963591837163fde5723ca1c6c37fd334389fa25d69
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ik6ven20/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0

# %%
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.transforms import functional as F
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       5 from PIL import Image
#       6 import cv2
# ----> 7 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'google'

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Receiving objects: 100% (16575/16575), 15.03 MiB | 39.27 MiB/s, done.
# Resolving deltas: 100% (11387/11387), done.
# /home/martynodlrr/obj-detection-YOLO/yolov5
# /home/martynodlrr/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib>=3.3
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.23.5 in /home/martynodlrr/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.26.3)
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=10.3.0
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil in /home/martynodlrr/.local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (5.9.8)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 KB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting requests>=2.23.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 KB 1.8 MB/s eta 0:00:00
# Collecting scipy>=1.4.1
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 4.8 MB/s eta 0:00:0000:0100:01
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.3.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.18.0+cu118)
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 2.9 MB/s eta 0:00:00
# Collecting ultralytics>=8.0.232
#   Downloading ultralytics-8.2.5-py3-none-any.whl (754 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 KB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting pandas>=1.1.4
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 4.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools>=65.5.1 in /home/martynodlrr/.local/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (69.0.2)
# Collecting wheel>=0.38.0
#   Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 KB 3.7 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.3 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.5 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 KB 4.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/martynodlrr/.local/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 3.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /home/martynodlrr/.local/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.11.17)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: fsspec in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.2.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.0.86)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.7.5.86)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.8.86)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.8.87)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.8.89)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (8.7.0.84)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.11.3.6)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.8.89)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.10.0)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.20.5)
# Requirement already satisfied: filelock in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: sympy in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: triton==2.3.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.4.1.48)
# Requirement already satisfied: jinja2 in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: networkx in /home/martynodlrr/.local/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 4.1 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 4.1 MB/s eta 0:00:00a 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/martynodlrr/.local/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/martynodlrr/.local/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Installing collected packages: pytz, py-cpuinfo, wheel, urllib3, tzdata, tqdm, smmap, scipy, PyYAML, pillow, opencv-python, kiwisolver, idna, fonttools, cycler, contourpy, charset-normalizer, requests, pandas, matplotlib, gitdb, thop, seaborn, gitpython, ultralytics
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
# Successfully installed PyYAML-6.0.1 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 gitdb-4.0.11 gitpython-3.1.43 idna-3.7 kiwisolver-1.4.5 matplotlib-3.8.4 opencv-python-4.9.0.80 pandas-2.2.2 pillow-10.3.0 py-cpuinfo-9.0.0 pytz-2024.1 requests-2.31.0 scipy-1.13.0 seaborn-0.13.2 smmap-5.0.1 thop-0.1.1.post2209072238 tqdm-4.66.2 tzdata-2024.1 ultralytics-8.2.5 urllib3-2.2.1 wheel-0.43.0

# %%
import torch
from yolov5.models.yolo import Model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True).to(device)
model.eval()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/martynodlrr/.cache/torch/hub/master.zip
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100.0%
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
  ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 from IPython.display import display, Javascript
# ----> 2 from google.colab.output import eval_js
#       3 from base64 import b64decode
#       5 def take_photo(filename='photo.jpg', quality=0.8):
#
# ModuleNotFoundError: No module named 'google'

# %%
def preprocess_image(image_path):
    image = Image.open(image_path)
    image_tensor = F.to_tensor(image)
    return image_tensor.unsqueeze(0).to(device)

# %%
def draw_boxes(image_path, outputs, threshold=0.3):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w, _ = image.shape

    for box in outputs:
        score, label, x1, y1, x2, y2 = box[4].item(), int(box[5].item()), box[0].item(), box[1].item(), box[2].item(), box[3].item()
        if score > threshold:
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
            text = f"{model.names[label]:s}: {score:.2f}"
            cv2.putText(image, text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    return image

# %%
from yolov5.utils.general import non_max_suppression
image_tensor = preprocess_image(image_path)
outputs = model(image_tensor)
outputs = non_max_suppression(outputs)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from yolov5.utils.general import non_max_suppression
# ----> 2 image_tensor = preprocess_image(image_path)
#       3 outputs = model(image_tensor)
#       4 outputs = non_max_suppression(outputs)[0]
#
# NameError: name 'image_path' is not defined

# %%
result_image = draw_boxes(image_path, outputs)
cv2_imshow(result_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result_image = draw_boxes(image_path, outputs)
#       2 cv2_imshow(result_image)
#
# NameError: name 'image_path' is not defined
